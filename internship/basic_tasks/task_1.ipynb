# %% [markdown]
# ## Implement a Simple Linear Regression

# %%
#importing neccessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
#loading dataset of tips from seaborn library
df=sns.load_dataset('tips')
print('First 5 Rows:\n',df.head())
print('Shape of Dataset: ',df.shape)
print('Statistical Operations on Dataset:\n',df.describe())
# Out:
# First 5 Rows:
#     total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# Shape of Dataset:  (244, 7)
# Statistical Operations on Dataset:
#         total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#separating X and y
X = df[['total_bill']]
y = df['tip']

# %%
#splitting data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#fitting Linear Regression model
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#predicting y for X_test
y_pred = model.predict(X_test)

#Evaluating model 
print('MAE:',mean_absolute_error(y_test,y_pred))
print('MSE:',mean_squared_error(y_test,y_pred))
print('RMSE:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('R2 Score',r2_score(y_test,y_pred))
# Out:
# MAE: 0.8371490158285403
# MSE: 1.2840815142462554
# RMSE: 1.1331732057572907
# R2 Score 0.18554050928917898

# %%
#plotting the Regression line
plt.scatter(X_test,y_test)
plt.plot(X_test, y_pred, color='red')
plt.show()

# %%
#Make predictions using model
print(model.predict([[1000]]))
print(model.predict([[100]]))
print(model.predict([[2678]]))
print(model.predict([[3700]]))
print(model.predict([[9000]]))
# Out:
# [108.56448741]
# [11.650779]
# [289.25471264]
# [399.30561263]
# [970.01967325]
# c:\Users\PMLS\.conda\envs\python_ml\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\PMLS\.conda\envs\python_ml\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\PMLS\.conda\envs\python_ml\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\PMLS\.conda\envs\python_ml\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
